# %% [markdown]
# # Recency, Frequency, Monetary Transaction Segmentation

# %%
# https://www.putler.com/rfm-analysis/#visuals
# github: https://www.bing.com/videos/search?q=youtube+github+in+15+minutes&view=detail&mid=72C8A6D7A4E82717835072C8A6D7A4E827178350&FORM=VIRE
# Best are High spending, Recent, Frequent - reward their loyalty 
# Bought recently, and more than once - Membership, loyalty program, sell other products (upsell add-ons, cross-sell other services)
# Bought recently but not often - help with onboarding
# About to sleep Not recent - reconnect with them, discount, personalised, new products 
# Lapsed customers - personalised comms
# Not customers - brand campaign
# https://www.kaggle.com/regivm/rfm-analysis-tutorial

# %%
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
from pycaret.classification import *
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
df = pd.read_csv('D:\\marke\\data\\retail\\Retail_Data_Transactions.csv', parse_dates=['trans_date'])

# %%
df.head(3)
# Out:
#   customer_id trans_date  tran_amount
# 0      CS5295 2013-02-11           35
# 1      CS4768 2015-03-15           39
# 2      CS2122 2013-02-26           52

# %%
len(df)
# Out:
# 125000

# %%
import sys
sys.getsizeof(df) # in bytes
# Out:
# 9875144

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125000 entries, 0 to 124999
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   customer_id  125000 non-null  object
#  1   trans_date   125000 non-null  datetime64[ns]
#  2   tran_amount  125000 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 9.4 MB

# %%
print(df['trans_date'].min(), df['trans_date'].max())
# Out:
# 2011-05-16 00:00:00 2015-03-16 00:00:00

# %%
sd = dt.datetime(2015,3,16)
df['hist']=sd - df['trans_date']
df['hist'].astype('timedelta64[D]')
df['hist']=df['hist'] / np.timedelta64(1, 'D')
df.head()
# Out:
#   customer_id trans_date  tran_amount    hist
# 0      CS5295 2013-02-11           35   763.0
# 1      CS4768 2015-03-15           39     1.0
# 2      CS2122 2013-02-26           52   748.0
# 3      CS1217 2011-11-16           99  1216.0
# 4      CS1850 2013-11-20           78   481.0

# %%
df=df[df['hist'] < 730]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 65023 entries, 1 to 124999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  65023 non-null  object
#  1   trans_date   65023 non-null  datetime64[ns]
#  2   tran_amount  65023 non-null  int64
#  3   hist         65023 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 2.5+ MB

# %%
rfmTable = df.groupby('customer_id').agg({'hist': lambda x:x.min(), # Recency
                                        'customer_id': lambda x: len(x),               # Frequency
                                        'tran_amount': lambda x: x.sum()})          # Monetary Value

rfmTable.rename(columns={'hist': 'recency', 
                         'customer_id': 'frequency', 
                         'tran_amount': 'monetary_value'}, inplace=True)

# %%
df[df['customer_id']=='CS1112']
# Out:
#       customer_id trans_date  tran_amount   hist
# 5650       CS1112 2015-01-14           39   61.0
# 17810      CS1112 2014-07-16           90  243.0
# 26626      CS1112 2014-04-29           63  321.0
# 31500      CS1112 2014-12-04           59  102.0
# 42084      CS1112 2013-07-01           36  623.0
# 74842      CS1112 2013-11-13           71  488.0

# %%
quartiles = rfmTable.quantile(q=[0.25,0.50,0.75])
print(quartiles, type(quartiles))
# Out:
#       recency  frequency  monetary_value
# 0.25     22.0        7.0           390.0
# 0.50     53.0        9.0           607.0
# 0.75    111.0       12.0           816.0 <class 'pandas.core.frame.DataFrame'>

# %%
quartiles=quartiles.to_dict()
quartiles
# Out:
# {'recency': {0.25: 22.0, 0.5: 53.0, 0.75: 111.0},
#  'frequency': {0.25: 7.0, 0.5: 9.0, 0.75: 12.0},
#  'monetary_value': {0.25: 390.0, 0.5: 607.0, 0.75: 816.0}}

# %%
## for Recency 

def RClass(x,p,d):
    if x <= d[p][0.25]:
        return 1
    elif x <= d[p][0.50]:
        return 2
    elif x <= d[p][0.75]: 
        return 3
    else:
        return 4
    
## for Frequency and Monetary value 

def FMClass(x,p,d):
    if x <= d[p][0.25]:
        return 4
    elif x <= d[p][0.50]:
        return 3
    elif x <= d[p][0.75]: 
        return 2
    else:
        return 1

# %%
rfmSeg = rfmTable
rfmSeg['R_Quartile'] = rfmSeg['recency'].apply(RClass, args=('recency',quartiles,))
rfmSeg['F_Quartile'] = rfmSeg['frequency'].apply(FMClass, args=('frequency',quartiles,))
rfmSeg['M_Quartile'] = rfmSeg['monetary_value'].apply(FMClass, args=('monetary_value',quartiles,))

# %%
rfmSeg['RFMClass'] = rfmSeg.R_Quartile.map(str) \
                            + rfmSeg.F_Quartile.map(str) \
                            + rfmSeg.M_Quartile.map(str)

# %%
rfmSeg.head()
# Out:
#              recency  frequency  monetary_value  R_Quartile  F_Quartile  \
# customer_id
# CS1112          61.0          6             358           3           4
# CS1113          35.0         11             775           2           2
# CS1114          32.0         11             804           2           2
# CS1115          11.0         11             831           1           2
# CS1116         203.0          5             333           4           4
#
#              M_Quartile RFMClass
# customer_id
# CS1112                4      344
# CS1113                2      222
# CS1114                2      222
# CS1115                1      121
# CS1116                4      444

# %%
rfmSeg.sort_values(by=['RFMClass', 'monetary_value'], ascending=[True, False])
# Out:
#              recency  frequency  monetary_value  R_Quartile  F_Quartile  \
# customer_id
# CS4640          18.0         21            1610           1           1
# CS5343          13.0         20            1585           1           1
# CS3622          13.0         20            1549           1           1
# CS3688          15.0         19            1459           1           1
# CS2316           3.0         21            1446           1           1
# ...              ...        ...             ...         ...         ...
# CS7972         335.0          1              26           4           4
# CS8033         483.0          1              24           4           4
# CS8400         446.0          1              19           4           4
# CS8760         447.0          1              19           4           4
# CS8740         469.0          1              17           4           4
#
#              M_Quartile RFMClass
# customer_id
# CS4640                1      111
# CS5343                1      111
# CS3622                1      111
# CS3688                1      111
# CS2316                1      111
# ...                 ...      ...
# CS7972                4      444
# CS8033                4      444
# CS8400                4      444
# CS8760                4      444
# CS8740                4      444
#
# [6884 rows x 7 columns]

# %%
rfmSeg.groupby('RFMClass').agg('monetary_value').mean()
# Out:
# RFMClass
# 111    1040.886214
# 112     750.666667
# 113     526.400000
# 121     876.818792
# 122     728.847561
# 123     506.773333
# 124     368.222222
# 132     665.492188
# 133     525.223404
# 134     328.179104
# 143     470.666667
# 144     270.844444
# 211    1040.580000
# 212     747.000000
# 213     525.833333
# 221     877.388489
# 222     722.018293
# 223     493.111111
# 224     347.285714
# 232     669.608333
# 233     520.100000
# 234     335.380000
# 242     617.750000
# 243     470.890625
# 244     261.939394
# 311    1038.503571
# 312     712.538462
# 313     563.857143
# 321     872.103448
# 322     731.386885
# 323     503.692308
# 324     356.666667
# 332     664.292308
# 333     526.143519
# 334     336.459016
# 342     610.500000
# 343     472.711538
# 344     249.600601
# 411    1008.403509
# 412     772.400000
# 413     542.000000
# 421     867.848101
# 422     726.048780
# 423     494.964286
# 424     355.142857
# 431     823.000000
# 432     662.414634
# 433     523.882653
# 434     330.442623
# 442     649.000000
# 443     468.022523
# 444     235.129134
# Name: monetary_value, dtype: float64

# %%
rfmSeg['Total Score'] = rfmSeg['R_Quartile'] + rfmSeg['F_Quartile'] +rfmSeg['M_Quartile']
print(rfmSeg.head(), rfmSeg.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6884 entries, CS1112 to CS9000
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   recency         6884 non-null   float64
#  1   frequency       6884 non-null   int64
#  2   monetary_value  6884 non-null   int64
#  3   R_Quartile      6884 non-null   int64
#  4   F_Quartile      6884 non-null   int64
#  5   M_Quartile      6884 non-null   int64
#  6   RFMClass        6884 non-null   object
#  7   Total Score     6884 non-null   int64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 484.0+ KB
#              recency  frequency  monetary_value  R_Quartile  F_Quartile  \
# customer_id
# CS1112          61.0          6             358           3           4
# CS1113          35.0         11             775           2           2
# CS1114          32.0         11             804           2           2
# CS1115          11.0         11             831           1           2
# CS1116         203.0          5             333           4           4
#
#              M_Quartile RFMClass  Total Score
# customer_id
# CS1112                4      344           11
# CS1113                2      222            6
# CS1114                2      222            6
# CS1115                1      121            4
# CS1116                4      444           12   None

# %%
res = pd.read_csv('D:\\marke\\data\\retail\\Retail_Data_Response.csv')
res.sort_values('customer_id', inplace=True)

print(res.head(), res.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6884 entries, 0 to 6883
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_id  6884 non-null   object
#  1   response     6884 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 161.3+ KB
#   customer_id  response
# 0      CS1112         0
# 1      CS1113         0
# 2      CS1114         1
# 3      CS1115         1
# 4      CS1116         1 None

# %%
rfmSeg.reset_index(inplace=True)
rfmSeg.head()
# Out:
#   customer_id  recency  frequency  monetary_value  R_Quartile  F_Quartile  \
# 0      CS1112     61.0          6             358           3           4
# 1      CS1113     35.0         11             775           2           2
# 2      CS1114     32.0         11             804           2           2
# 3      CS1115     11.0         11             831           1           2
# 4      CS1116    203.0          5             333           4           4
#
#    M_Quartile RFMClass  Total Score
# 0           4      344           11
# 1           2      222            6
# 2           2      222            6
# 3           1      121            4
# 4           4      444           12

# %%
rfmSeg.sort_values('customer_id', inplace=True)
rfm2=pd.merge(rfmSeg, res, on='customer_id')

# %%
rfm2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6884 entries, 0 to 6883
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     6884 non-null   object
#  1   recency         6884 non-null   float64
#  2   frequency       6884 non-null   int64
#  3   monetary_value  6884 non-null   int64
#  4   R_Quartile      6884 non-null   int64
#  5   F_Quartile      6884 non-null   int64
#  6   M_Quartile      6884 non-null   int64
#  7   RFMClass        6884 non-null   object
#  8   Total Score     6884 non-null   int64
#  9   response        6884 non-null   int64
# dtypes: float64(1), int64(7), object(2)
# memory usage: 591.6+ KB

# %%
# Build a Customer Propensity model to predict response from
label = rfm2.groupby('response').agg({'customer_id': lambda x: len(x)})
label.head()
# Out:
#           customer_id
# response
# 0                6237
# 1                 647

# %%
training_df = rfm2[['response','recency','frequency','monetary_value']]

# %%
training_df.head()
# Out:
#    response  recency  frequency  monetary_value
# 0         0     61.0          6             358
# 1         0     35.0         11             775
# 2         1     32.0         11             804
# 3         1     11.0         11             831
# 4         1    203.0          5             333

# %%
experiment_allModels = setup(training_df, target='response', silent = True, use_gpu = True, train_size=0.8,fix_imbalance=True)
# Out:
# <style  type="text/css" >
# #T_d6397d82_7759_11eb_a63a_c8d3ffe77231row18_col1,#T_d6397d82_7759_11eb_a63a_c8d3ffe77231row56_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_d6397d82_7759_11eb_a63a_c8d3ffe77231" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d6397d82_7759_11eb_a63a_c8d3ffe77231level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d6397d82_7759_11eb_a63a_c8d3ffe77231row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_d6397d82_7759_11eb_a63a_c8d3ffe77231row0_col1" class="data row0 col1" >8088</td>
#             </tr>
#             <tr>
#                         <th id="T_d6397d82_7759_11eb_a63a_c8d3ffe77231level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d6397d82_7759_11eb_a63a_c8d3ffe77231row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_d6397d82_7759_11eb_a63a_c8d3ffe77231row1_col1" class="data row1 col1" >response</td>
#             </tr>
#             <tr>
#                         <th id="T_d6397d82_7759_11eb_a63a_c8d3ffe77231level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T

#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_0e311fbb_775a_11eb_afb5_c8d3ffe77231row0_col8,#T_0e311fbb_775a_11eb_afb5_c8d3ffe77231row1_col8,#T_0e311fbb_775a_11eb_afb5_c8d3ffe77231row2_col8,#T_0e311fbb_775a_11eb_afb5_c8d3ffe77231row3_col8,#T_0e311fbb_775a_11eb_afb5_c8d3ffe77231row4_col8,#T_0e311fbb_775a_11eb_afb5_c8d3ffe77231row5_col8,#T_0e311fbb_775a_11eb_afb5_c8d3ffe77231row6_col8,#T_0e311fbb_775a_11eb_afb5_c8d3ffe77231row7_col8,#T_0e311fbb_775a_11eb_afb5_c8d3ffe77231row8_col8,#T_0e311fbb_775a_11eb_afb5_c8d3ffe77231row9_col8,#T_0e311fbb_775a_11eb_afb5_c8d3ffe77231row14_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_0e311fbb_775a_11eb_afb5_c8d3ffe77231row10_col8,#T_0e311fbb_775a_11eb_afb5_c8d3ffe77231row11_col8,#T_0e311fbb_775a_11eb_afb5_c8d3ffe77231row12_col8,#T_0e311fbb_775a_11eb_afb5_c8d3ffe77231row13_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_0e311fbb_775a_11eb_afb5_c8d3ffe77231" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0e311fbb_775a_11eb_afb5_c8d3ffe77231level0_row0" class="row_heading level0 row0" >xgboost</th

# %%
dt = create_model('dt', fold=10)
# Out:
# <style  type="text/css" >
# #T_0e80d1f3_775a_11eb_8e12_c8d3ffe77231row10_col0,#T_0e80d1f3_775a_11eb_8e12_c8d3ffe77231row10_col1,#T_0e80d1f3_775a_11eb_8e12_c8d3ffe77231row10_col2,#T_0e80d1f3_775a_11eb_8e12_c8d3ffe77231row10_col3,#T_0e80d1f3_775a_11eb_8e12_c8d3ffe77231row10_col4,#T_0e80d1f3_775a_11eb_8e12_c8d3ffe77231row10_col5,#T_0e80d1f3_775a_11eb_8e12_c8d3ffe77231row10_col6{
#             background:  yellow;
#         }</style><table id="T_0e80d1f3_775a_11eb_8e12_c8d3ffe77231" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T
0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_0e80d1f3_775a_11eb_8e12_c8d3ffe77231row6_col0" class="data row6 col0" >0.8421</td>
#                         <td id="T_0e80d1f3_775a_11eb_8e12_c8d3ffe77231row6_col1" class="data row6 col1" >0.5941</td>
#                         <td id="T_0e80d1f3_775a_11eb_8e12_c8d3ffe77231row6_col2" class="data row6 col2" >0.2885</td>
#                         <td id="T_0e80d1f3_775a_11eb_8e12_c8d3ffe77231row6_col3" class="data row6 col3" >0.2308</td>
#                         <td id="T_0e80d1f3_775a_11eb_8e12_c8d3ffe77231row6_col4" class="data row6 col4" >0.2564</td>
#                         <td id="T_0e80d1f3_775a_11eb_8e12_c8d3ffe77231row6_col5" class="data row6 col5" >0.1693</td>
#                         <td id="T_0e80d1f3_775a_11eb_8e12_c8d3ffe77231row6_col6" class="data row6 col6" >0.1706</td>
#             </tr>
#             <tr>
#                         <th id="T_0e80d1f3_775a_11eb_8e12_c8d3ffe77231level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_0e80d1f3_775a_11eb_8e12_c8d3ffe77231row7_co

# %%
dt_model_tuned = tune_model(dt)
# Out:
# <style  type="text/css" >
# #T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row10_col0,#T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row10_col1,#T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row10_col2,#T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row10_col3,#T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row10_col4,#T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row10_col5,#T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row10_col6{
#             background:  yellow;
#         }</style><table id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row0_col0" class="data row0 col0" >0.9074</td>
#                         <td id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row0_col1" class="data row0 col1" >0.5000</td>
#                         <td id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row0_col2" class="data row0 col2" >0.0000</td>
#                         <td id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row0_col3" class="data row0 col3" >0.0000</td>
#                         <td id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row0_col4" class="data row0 col4" >0.0000</td>
#                         <td id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row0_col5" class="data row0 col5" >0.0000</td>
#                         <td id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row0_col6" class="data row0 col6" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T
#                         <td id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row4_col4" class="data row4 col4" >0.0000</td>
#                         <td id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row4_col5" class="data row4 col5" >0.0000</td>
#                         <td id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row4_col6" class="data row4 col6" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row5_col0" class="data row5 col0" >0.9056</td>
#                         <td id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row5_col1" class="data row5 col1" >0.5000</td>
#                         <td id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row5_col2" class="data row5 col2" >0.0000</td>
#                         <td id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row5_col3" class="data row5 col3" >0.0000</td>
#                         <td id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row5_col4" class="data row5 col4" >0.0000</td>
#                         <td id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row5_col5" class="data row5 col5" >0.0000</td>
#                         <td id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row5_col6" class="data row5 col6" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row6_col0" class="data row6 col0" >0.9056</td>
#                         <td id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row6_col1" class="data row6 col1" >0.5000</td>
#                         <td id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row6_col2" class="data row6 col2" >0.0000</td>
#                         <td id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row6_col3" class="data row6 col3" >0.0000</td>
#                         <td id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row6_col4" class="data row6 col4" >0.0000</td>
#                         <td id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row6_col5" class="data row6 col5" >0.0000</td>
#                         <td id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row6_col6" class="data row6 col6" >0.0000</td>
#             </tr>
#             <tr>
#                         <th id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_1015ed9a_775a_11eb_96b3_c8d3ffe77231row7_co

# %%
#tuned model parameters
print(dt_model_tuned)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=8, max_features='sqrt', max_leaf_nodes=None,
#                        min_impurity_decrease=0.4, min_impurity_split=None,
#                        min_samples_leaf=5, min_samples_split=9,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=8088, splitter='best')

# %%
evaluate_model(lr_model_tuned)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-93622cb9667e> in <module>
# ----> 1 evaluate_model(lr_model_tuned)
#
# NameError: name 'lr_model_tuned' is not defined

# %%
# Sort a dataframe

df.sort

# %%
# pivot table

# %%
# group and aggregate, count

# %%
# subset
